# %%
import numpy as np
def compute_integral(c0, c1, dt, d):
    alpha = np.exp(-d*dt)
    X = (-d*dt*alpha + 1 - alpha)
    Y = (d*dt-1) + alpha
    return (X*c0+Y*c1)/d/dt
# def compute_integral(c0, c1, t0, t1, d):
#     X = np.exp(-d*t1) + np.exp(-d*t0) * (d*(-t0+t1)-1)
#     Y = np.exp(-d*t1) * (d*(t0-t1)-1) + np.exp(-d*t0)
#     C = d * (t0-t1)**2
#     return (X * c0+ Y * c1) / C
#     numer = (t0+t1) * (1-d * (t0-t1))
#     X = numer * np.exp(d * t1)
#     Y = numer * np.exp(d * t0)
#     C = d * np.exp(d * (t1+t0)) * (t0-t1)**2
#     print(X, Y, C)
#     return (X * c0 + Y * c1) / C

print(compute_integral(1, 1, 2, 1))
print(1-np.exp(-2))
print((np.exp(0)-np.exp(1)) / -np.exp(1))
# Out:
# 0.8646647167633874
# 0.8646647167633873
# 0.6321205588285577
